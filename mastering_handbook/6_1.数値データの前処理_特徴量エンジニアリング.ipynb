# %% [markdown]
# ## 6_1.数値データの前処理_特徴量エンジニアリン

# %%
import pandas as pd

# CSVファイルのデータをデータフレームに読み込む
df = pd.read_csv('scoring.csv')
df
# Out:
#       A     B
# 0  70.0  80.0
# 1  70.0  75.0
# 2  70.0  80.0
# 3   NaN  85.0
# 4  90.0  85.0
# 5  70.0  90.0
# 6  80.0  75.0
# 7  70.0   NaN
# 8  70.0   NaN
# 9  85.0  90.0

# %%
#　全ての欠損地をその列の平均値に置き換える
df.fillna(df.mean())
# Out:
#       A     B
# 0  70.0  80.0
# 1  70.0  75.0
# 2  70.0  80.0
# 3  75.0  85.0
# 4  90.0  85.0
# 5  70.0  90.0
# 6  80.0  75.0
# 7  70.0  82.5
# 8  70.0  82.5
# 9  85.0  90.0

# %%
# 全ての欠損値をその列の中央値に置き換える
df.fillna(df.median())
# Out:
#       A     B
# 0  70.0  80.0
# 1  70.0  75.0
# 2  70.0  80.0
# 3  70.0  85.0
# 4  90.0  85.0
# 5  70.0  90.0
# 6  80.0  75.0
# 7  70.0  82.5
# 8  70.0  82.5
# 9  85.0  90.0
